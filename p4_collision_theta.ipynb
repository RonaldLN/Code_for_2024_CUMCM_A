# %%
from utils import *
import numpy as np

positions_out = calculate_spiral_positions(8, pitch=-1.7, d1=2.2 - 0.275 * 2)

def check_collision_between_spirals(positions_in, positions_out, width, node_to_edge_distance):
    """
    Check if the rectangle on the first spiral at theta collides with the bench on the second spiral.
    
    Args:
        width (float): The width of the rectangle.
        node_to_edge_distance (float): The distance from the node to the edge of the rectangle.
        
    Returns:
        bool: True if a collision is detected, False otherwise.
    """
    head_rect_nodes = [positions_in[0][:2], positions_in[1][:2]]
    head_theta = positions_in[0][2]

    for i in range(len(positions_out) - 1):
        if positions_out[i][2] < head_theta - 2 * np.pi:
            continue
        
        rect_nodes = [positions_out[i][:2], positions_out[i + 1][:2]]
        if positions_out[i][2] < head_theta:
            if check_collision(rect_nodes, head_rect_nodes, width, node_to_edge_distance):
                return True
        elif positions_out[i][2] < head_theta + 2 * np.pi:
            if check_collision(head_rect_nodes, rect_nodes, width, node_to_edge_distance):
                return True
        else:
            break
    return False

def find_critical_theta_for_collision(width, node_to_edge_distance, initial_theta=0, theta_step=0.01, precision=1e-6):
    """
    Find the critical theta at which a collision occurs between the rectangles on two spirals.
    
    Args:
        width (float): The width of the rectangles.
        node_to_edge_distance (float): The distance from the node to the edge of the rectangle.
        initial_theta (float): Starting theta value to check for collisions.
        theta_step (float): Step size to increment theta.
        precision (float): Desired precision for finding the exact collision theta.
    
    Returns:
        float: The critical theta value at which a collision occurs.
    """
    theta = initial_theta

    while theta_step > precision:
        collision_occurred = False
        while not collision_occurred:
            # Calculate the positions of nodes on the first spiral
            positions_in = calculate_spiral_positions(theta, pitch=1.7)

            # Check if there is a collision at this theta
            if check_collision_between_spirals(positions_in, positions_out, width, node_to_edge_distance):
                collision_occurred = True
            else:
                # Increment the theta by the step size
                theta -= theta_step
        
        # Reduce the step size for more precision and adjust the theta
        theta += theta_step  # Go back to the start of the interval where collision was first detected
        theta_step /= 10  # Reduce step size for finer checking

    return theta

if __name__ == "__main__":
    # Example usage
    width = 0.3  # Width of the rectangles
    node_to_edge_distance = 0.275  # Distance from node to rectangle edge
    initial_theta = 4.5 * 2 * np.pi / 1.7

    # Find the critical theta for collision
    # critical_theta = find_critical_theta_for_collision(initial_theta=initial_theta, width=width, node_to_edge_distance=node_to_edge_distance)
    # print(f"Collision occurs at approximately theta = {critical_theta:.6f} radians.")

    output = []

    for theta in range(30, 100):
        positions_out = calculate_spiral_positions(theta / 10, pitch=-1.7, d1=2.2 - 0.275 * 2)
        critical_theta = find_critical_theta_for_collision(initial_theta=initial_theta, width=width, node_to_edge_distance=node_to_edge_distance)
        output.append(f"When theta_s_out = {theta / 10}, collision occurs at approximately theta = {critical_theta:.6f} radians.")

    for line in output:
        print(line)
# Out:
# When theta_s_out = 3.0, collision occurs at approximately theta = 9.709771 radians.
# When theta_s_out = 3.1, collision occurs at approximately theta = 6.195804 radians.
# When theta_s_out = 3.2, collision occurs at approximately theta = 8.544667 radians.
# When theta_s_out = 3.3, collision occurs at approximately theta = 12.196060 radians.
# When theta_s_out = 3.4, collision occurs at approximately theta = 6.473620 radians.
# When theta_s_out = 3.5, collision occurs at approximately theta = 6.563446 radians.
# When theta_s_out = 3.6, collision occurs at approximately theta = 6.653739 radians.
# When theta_s_out = 3.7, collision occurs at approximately theta = 6.744482 radians.
# When theta_s_out = 3.8, collision occurs at approximately theta = 12.274486 radians.
# When theta_s_out = 3.9, collision occurs at approximately theta = 9.816804 radians.
# When theta_s_out = 4.0, collision occurs at approximately theta = 11.722370 radians.
# When theta_s_out = 4.1, collision occurs at approximately theta = 7.269215 radians.
# When theta_s_out = 4.2, collision occurs at approximately theta = 7.349137 radians.
# When theta_s_out = 4.3, collision occurs at approximately theta = 9.660789 radians.
# When theta_s_out = 4.4, collision occurs at approximately theta = 7.485979 radians.
# When theta_s_out = 4.5, collision occurs at approximately theta = 8.765074 radians.
# When theta_s_out = 4.6, collision occurs at approximately theta = 10.868935 radians.
# When theta_s_out = 4.7, collision occurs at approximately theta = 12.318797 radians.
# When theta_s_out = 4.8, collision occurs at approximately theta = 8.443964 radians.
# When theta_s_out = 4.9, collision occurs at approximately theta = 12.201423 radians.
# When theta_s_out = 5.0, collision occurs at approximately theta = 8.523800 radians.
# When theta_s_out = 5.1, collision occurs at approximately theta = 8.577134 radians.
# When theta_s_out = 5.2, collision occurs at approximately theta = 8.439534 radians.
# When theta_s_out = 5.3, collision occurs at approximately theta = 8.724776 radians.
# When theta_s_out = 5.4, collision occurs at approximately theta = 11.718430 radians.
# When theta_s_out = 5.5, collision occurs at approximately theta = 8.428449 radians.
# When theta_s_out = 5.6, collision occurs at approximately theta = 9.691168 radians.
# When theta_s_out = 5.7, collision occurs at approximately theta = 12.325492 radians.
# When theta_s_out = 5.8, collision occurs at approximately theta = 8.722574 radians.
# When theta_s_out = 5.9, collision occurs at approximately theta = 12.315563 radians.
# When theta_s_out = 6.0, collision occurs at approximately theta = 12.221316 radians.
# When theta_s_out = 6.1, collision occurs at approximately theta = 12.165770 radians.
# When theta_s_out = 6.2, collision occurs at approximately theta = 9.681034 radians.
# When theta_s_out = 6.3, collision occurs at approximately theta = 10.987993 radians.
# When theta_s_out = 6.4, collision occurs at approximately theta = 9.305803 radians.
# When theta_s_out = 6.5, collision occurs at approximately theta = 9.402523 radians.
# When theta_s_out = 6.6, collision occurs at approximately theta = 11.003593 radians.
# When theta_s_out = 6.7, collision occurs at approximately theta = 12.321945 radians.
# When theta_s_out = 6.8, collision occurs at approximately theta = 9.691984 radians.
# When theta_s_out = 6.9, collision occurs at approximately theta = 9.788244 radians.
# When theta_s_out = 7.0, collision occurs at approximately theta = 11.717001 radians.
# When theta_s_out = 7.1, collision occurs at approximately theta = 9.980426 radians.
# When theta_s_out = 7.2, collision occurs at approximately theta = 11.255635 radians.
# When theta_s_out = 7.3, collision occurs at approximately theta = 10.172137 radians.
# When theta_s_out = 7.4, collision occurs at approximately theta = 12.275227 radians.
# When theta_s_out = 7.5, collision occurs at approximately theta = 10.363341 radians.
# When theta_s_out = 7.6, collision occurs at approximately theta = 10.868529 radians.
# When theta_s_out = 7.7, collision occurs at approximately theta = 10.553974 radians.
# When theta_s_out = 7.8, collision occurs at approximately theta = 10.965851 radians.
# When theta_s_out = 7.9, collision occurs at approximately theta = 10.878501 radians.
# When theta_s_out = 8.0, collision occurs at approximately theta = 10.838646 radians.
# When theta_s_out = 8.1, collision occurs at approximately theta = 10.933126 radians.
# When theta_s_out = 8.2, collision occurs at approximately theta = 11.027362 radians.
# When theta_s_out = 8.3, collision occurs at approximately theta = 12.188301 radians.
# When theta_s_out = 8.4, collision occurs at approximately theta = 11.723976 radians.
# When theta_s_out = 8.5, collision occurs at approximately theta = 12.324963 radians.
# When theta_s_out = 8.6, collision occurs at approximately theta = 12.204300 radians.
# When theta_s_out = 8.7, collision occurs at approximately theta = 11.493434 radians.
# When theta_s_out = 8.8, collision occurs at approximately theta = 11.585153 radians.
# When theta_s_out = 8.9, collision occurs at approximately theta = 11.676097 radians.
# When theta_s_out = 9.0, collision occurs at approximately theta = 11.766039 radians.
# When theta_s_out = 9.1, collision occurs at approximately theta = 11.854623 radians.
# When theta_s_out = 9.2, collision occurs at approximately theta = 11.941231 radians.
# When theta_s_out = 9.3, collision occurs at approximately theta = 12.317896 radians.
# When theta_s_out = 9.4, collision occurs at approximately theta = 12.101180 radians.
# When theta_s_out = 9.5, collision occurs at approximately theta = 11.643138 radians.
# When theta_s_out = 9.6, collision occurs at approximately theta = 11.744402 radians.
# When theta_s_out = 9.7, collision occurs at approximately theta = 11.845008 radians.
# When theta_s_out = 9.8, collision occurs at approximately theta = 11.944873 radians.
# When theta_s_out = 9.9, collision occurs at approximately theta = 12.043878 radians.

# %%
from utils import *
import numpy as np

positions_out = calculate_spiral_positions(8, pitch=-1.7, d1=2.2 - 0.275 * 2)

def check_collision_between_spirals(positions_in, positions_out, width, node_to_edge_distance):
    """
    Check if the rectangle on the first spiral at theta collides with the bench on the second spiral.
    
    Args:
        width (float): The width of the rectangle.
        node_to_edge_distance (float): The distance from the node to the edge of the rectangle.
        
    Returns:
        bool: True if a collision is detected, False otherwise.
    """
    head_rect_nodes = [positions_in[0][:2], positions_in[1][:2]]
    head_theta = positions_in[0][2]

    for i in range(len(positions_out) - 1):
        if positions_out[i][2] < head_theta - 2 * np.pi:
            continue
        
        rect_nodes = [positions_out[i][:2], positions_out[i + 1][:2]]
        if positions_out[i][2] < head_theta:
            if check_collision(rect_nodes, head_rect_nodes, width, node_to_edge_distance):
                return True, False
        elif positions_out[i][2] < head_theta + 2 * np.pi:
            if check_collision(head_rect_nodes, rect_nodes, width, node_to_edge_distance):
                return False, True
        else:
            break
    return False, False

def find_critical_theta_for_collision(width, node_to_edge_distance, initial_theta=0, theta_step=0.01, precision=1e-6):
    """
    Find the critical theta at which a collision occurs between the rectangles on two spirals.
    
    Args:
        width (float): The width of the rectangles.
        node_to_edge_distance (float): The distance from the node to the edge of the rectangle.
        initial_theta (float): Starting theta value to check for collisions.
        theta_step (float): Step size to increment theta.
        precision (float): Desired precision for finding the exact collision theta.
    
    Returns:
        float: The critical theta value at which a collision occurs.
    """
    theta = initial_theta

    collision_occurred_in = False
    collision_occurred_out = False

    while theta_step > precision:
        collision_occurred = False
        while not collision_occurred:
            # Calculate the positions of nodes on the first spiral
            positions_in = calculate_spiral_positions(theta, pitch=1.7)

            # Check if there is a collision at this theta
            collision_occurred_in, collision_occurred_out = check_collision_between_spirals(positions_in, positions_out, width, node_to_edge_distance)
            if collision_occurred_in or collision_occurred_out:
                collision_occurred = True
            else:
                # Increment the theta by the step size
                theta -= theta_step
        
        # Reduce the step size for more precision and adjust the theta
        theta += theta_step  # Go back to the start of the interval where collision was first detected
        theta_step /= 10  # Reduce step size for finer checking

    return theta, collision_occurred_in, collision_occurred_out

if __name__ == "__main__":
    # Example usage
    width = 0.3  # Width of the rectangles
    node_to_edge_distance = 0.275  # Distance from node to rectangle edge
    initial_theta = 4.5 * 2 * np.pi / 1.7

    # Find the critical theta for collision
    # critical_theta = find_critical_theta_for_collision(initial_theta=initial_theta, width=width, node_to_edge_distance=node_to_edge_distance)
    # print(f"Collision occurs at approximately theta = {critical_theta:.6f} radians.")

    output = []

    for theta in range(30, 100):
        positions_out = calculate_spiral_positions(theta / 10, pitch=-1.7, d1=2.2 - 0.275 * 2)
        critical_theta, collision_occurred_in, collision_occurred_out = find_critical_theta_for_collision(initial_theta=initial_theta, width=width, node_to_edge_distance=node_to_edge_distance)
        output.append(f"When {theta / 10}, collision theta = {critical_theta:.6f} radians " + ("INSIDE" if collision_occurred_in else "OUTSIDE"))

    for line in output:
        print(line)
# Out:
# c:\Users\Ronald\Downloads\24数模国赛\code\utils\p1_position.py:40: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   theta_next_solution = fsolve(equation, theta_next_initial_guess)[0]
# c:\Users\Ronald\Downloads\24数模国赛\code\utils\p1_position.py:40: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   theta_next_solution = fsolve(equation, theta_next_initial_guess)[0]
# When 3.0, collision theta = 9.709771 radians INSIDE
# When 3.1, collision theta = 6.195804 radians INSIDE
# When 3.2, collision theta = 8.544667 radians INSIDE
# When 3.3, collision theta = 12.196060 radians INSIDE
# When 3.4, collision theta = 6.473620 radians INSIDE
# When 3.5, collision theta = 6.563446 radians INSIDE
# When 3.6, collision theta = 6.653739 radians INSIDE
# When 3.7, collision theta = 6.744482 radians INSIDE
# When 3.8, collision theta = 12.274486 radians INSIDE
# When 3.9, collision theta = 9.816804 radians INSIDE
# When 4.0, collision theta = 11.722370 radians INSIDE
# When 4.1, collision theta = 7.269215 radians INSIDE
# When 4.2, collision theta = 7.349137 radians INSIDE
# When 4.3, collision theta = 9.660789 radians INSIDE
# When 4.4, collision theta = 7.485979 radians INSIDE
# When 4.5, collision theta = 8.765074 radians INSIDE
# When 4.6, collision theta = 10.868935 radians INSIDE
# When 4.7, collision theta = 12.318797 radians INSIDE
# When 4.8, collision theta = 8.443964 radians INSIDE
# When 4.9, collision theta = 12.201423 radians INSIDE
# When 5.0, collision theta = 8.523800 radians INSIDE
# When 5.1, collision theta = 8.577134 radians INSIDE
# When 5.2, collision theta = 8.439534 radians INSIDE
# When 5.3, collision theta = 8.724776 radians INSIDE
# When 5.4, collision theta = 11.718430 radians INSIDE
# When 5.5, collision theta = 8.428449 radians INSIDE
# When 5.6, collision theta = 9.691168 radians INSIDE
# When 5.7, collision theta = 12.325492 radians INSIDE
# When 5.8, collision theta = 8.722574 radians INSIDE
# When 5.9, collision theta = 12.315563 radians INSIDE
# When 6.0, collision theta = 12.221316 radians INSIDE
# When 6.1, collision theta = 12.165770 radians INSIDE
# When 6.2, collision theta = 9.681034 radians INSIDE
# When 6.3, collision theta = 10.987993 radians INSIDE
# When 6.4, collision theta = 9.305803 radians INSIDE
# When 6.5, collision theta = 9.402523 radians INSIDE
# When 6.6, collision theta = 11.003593 radians INSIDE
# When 6.7, collision theta = 12.321945 radians INSIDE
# When 6.8, collision theta = 9.691984 radians INSIDE
# When 6.9, collision theta = 9.788244 radians INSIDE
# When 7.0, collision theta = 11.717001 radians INSIDE
# When 7.1, collision theta = 9.980426 radians INSIDE
# When 7.2, collision theta = 11.255635 radians INSIDE
# When 7.3, collision theta = 10.172137 radians INSIDE
# When 7.4, collision theta = 12.275227 radians INSIDE
# When 7.5, collision theta = 10.363341 radians INSIDE
# When 7.6, collision theta = 10.868529 radians INSIDE
# When 7.7, collision theta = 10.553974 radians INSIDE
# When 7.8, collision theta = 10.965851 radians INSIDE
# When 7.9, collision theta = 10.878501 radians INSIDE
# When 8.0, collision theta = 10.838646 radians INSIDE
# When 8.1, collision theta = 10.933126 radians INSIDE
# When 8.2, collision theta = 11.027362 radians INSIDE
# When 8.3, collision theta = 12.188301 radians INSIDE
# When 8.4, collision theta = 11.723976 radians INSIDE
# When 8.5, collision theta = 12.324963 radians INSIDE
# When 8.6, collision theta = 12.204300 radians INSIDE
# When 8.7, collision theta = 11.493434 radians INSIDE
# When 8.8, collision theta = 11.585153 radians INSIDE
# When 8.9, collision theta = 11.676097 radians INSIDE
# When 9.0, collision theta = 11.766039 radians INSIDE
# When 9.1, collision theta = 11.854623 radians INSIDE
# When 9.2, collision theta = 11.941231 radians INSIDE
# When 9.3, collision theta = 12.317896 radians INSIDE
# When 9.4, collision theta = 12.101180 radians INSIDE
# When 9.5, collision theta = 11.643138 radians INSIDE
# When 9.6, collision theta = 11.744402 radians INSIDE
# When 9.7, collision theta = 11.845008 radians INSIDE
# When 9.8, collision theta = 11.944873 radians INSIDE
# When 9.9, collision theta = 12.043878 radians INSIDE
